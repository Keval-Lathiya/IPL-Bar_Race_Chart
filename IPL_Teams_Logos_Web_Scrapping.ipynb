# %%
import requests
from bs4 import BeautifulSoup
import os

# Define a user-agent string to include with your requests
headers = {
    'User-Agent': 'Chrome/58.0.3029.110'
}

# List of IPL teams
teams = [
    'Gujarat Titans', 'Rajasthan Royals', 'Royal Challengers Bangalore', 'Punjab Kings', 'Mumbai Indians',
    'Lucknow Super Giants', 'Sunrisers Hyderabad', 'Delhi Capitals', 'Kolkata Knight Riders', 'Chennai Super Kings',
    'Rising Pune Supergiant', 'Gujarat Lions', 'Rising Pune Supergiants', 'Pune Warriors', 'Deccan Chargers',
    'Kochi Tuskers Kerala'
]

# Base URL for Wikipedia pages
base_url = "https://en.wikipedia.org/wiki/"

# Directory to save the logos
logos_dir = "ipl_logos"
os.makedirs(logos_dir, exist_ok=True)

# Loop through each team
for team in teams:
    # Replace spaces with underscores for the URL
    team_url = base_url + team.replace(" ", "_")
    
    # Fetch the team's Wikipedia page with a user-agent
    response = requests.get(team_url, headers=headers)
    
    if response.status_code == 200:
        # Parse the HTML content
        soup = BeautifulSoup(response.content, 'html.parser')
        
        # Find the meta tag with the logo image URL
        logo_image_meta = soup.find("meta", property="og:image")
        
        if logo_image_meta:
            # Extract the content of the meta tag, which is the URL of the logo
            logo_url = logo_image_meta["content"]
            print(f"Downloading {team} logo from: {logo_url}")
            
            # Fetch the logo image with a user-agent
            logo_response = requests.get(logo_url, headers=headers)
            if logo_response.status_code == 200:
                # Define the path where the logo will be saved
                logo_path = os.path.join(logos_dir, f"{team.replace(' ', '_')}.png")
                
                # Open a file to write in binary mode and save the content
                with open(logo_path, 'wb') as f:
                    f.write(logo_response.content)
                print(f"Saved {team} logo to {logo_path}")
            else:
                print(f"Failed to download logo for {team}. Status code: {logo_response.status_code}")
        else:
            print(f"Logo URL not found for {team}.")
    else:
        print(f"Failed to fetch page for {team}. Status code: {response.status_code}")
# Out:
# Downloading Gujarat Titans logo from: https://upload.wikimedia.org/wikipedia/en/thumb/0/09/Gujarat_Titans_Logo.svg/1200px-Gujarat_Titans_Logo.svg.png
# Saved Gujarat Titans logo to ipl_logos\Gujarat_Titans.png
# Downloading Rajasthan Royals logo from: https://upload.wikimedia.org/wikipedia/en/thumb/5/5c/This_is_the_logo_for_Rajasthan_Royals%2C_a_cricket_team_playing_in_the_Indian_Premier_League_%28IPL%29.svg/1200px-This_is_the_logo_for_Rajasthan_Royals%2C_a_cricket_team_playing_in_the_Indian_Premier_League_%28IPL%29.svg.png
# Saved Rajasthan Royals logo to ipl_logos\Rajasthan_Royals.png
# Downloading Royal Challengers Bangalore logo from: https://upload.wikimedia.org/wikipedia/en/thumb/2/2a/Royal_Challengers_Bangalore_2020.svg/1200px-Royal_Challengers_Bangalore_2020.svg.png
# Saved Royal Challengers Bangalore logo to ipl_logos\Royal_Challengers_Bangalore.png
# Downloading Punjab Kings logo from: https://upload.wikimedia.org/wikipedia/en/thumb/d/d4/Punjab_Kings_Logo.svg/1200px-Punjab_Kings_Logo.svg.png
# Saved Punjab Kings logo to ipl_logos\Punjab_Kings.png
# Downloading Mumbai Indians logo from: https://upload.wikimedia.org/wikipedia/en/thumb/c/cd/Mumbai_Indians_Logo.svg/1200px-Mumbai_Indians_Logo.svg.png
# Saved Mumbai Indians logo to ipl_logos\Mumbai_Indians.png
# Downloading Lucknow Super Giants logo from: https://upload.wikimedia.org/wikipedia/en/thumb/a/a9/Lucknow_Super_Giants_IPL_Logo.svg/1200px-Lucknow_Super_Giants_IPL_Logo.svg.png
# Saved Lucknow Super Giants logo to ipl_logos\Lucknow_Super_Giants.png
# Downloading Sunrisers Hyderabad logo from: https://upload.wikimedia.org/wikipedia/en/e/eb/Sunrisers_Hyderabad.png
# Saved Sunrisers Hyderabad logo to ipl_logos\Sunrisers_Hyderabad.png
# Downloading Delhi Capitals logo from: https://upload.wikimedia.org/wikipedia/en/thumb/2/2f/Delhi_Capitals.svg/1200px-Delhi_Capitals.svg.png
# Saved Delhi Capitals logo to ipl_logos\Delhi_Capitals.png
# Downloading Kolkata Knight Riders logo from: https://upload.wikimedia.org/wikipedia/en/thumb/4/4c/Kolkata_Knight_Riders_Logo.svg/1200px-Kolkata_Knight_Riders_Logo.svg.png
# Saved Kolkata Knight Riders logo to ipl_logos\Kolkata_Knight_Riders.png
# Downloading Chennai Super Kings logo from: https://upload.wikimedia.org/wikipedia/en/thumb/2/2b/Chennai_Super_Kings_Logo.svg/1200px-Chennai_Super_Kings_Logo.svg.png
# Saved Chennai Super Kings logo to ipl_logos\Chennai_Super_Kings.png
# Downloading Rising Pune Supergiant logo from: https://upload.wikimedia.org/wikipedia/en/9/9a/Rising_Pune_Supergiant.png
# Saved Rising Pune Supergiant logo to ipl_logos\Rising_Pune_Supergiant.png
# Downloading Gujarat Lions logo from: https://upload.wikimedia.org/wikipedia/en/c/c4/Gujarat_Lions.png
# Saved Gujarat Lions logo to ipl_logos\Gujarat_Lions.png
# Downloading Rising Pune Supergiants logo from: https://upload.wikimedia.org/wikipedia/en/9/9a/Rising_Pune_Supergiant.png
# Saved Rising Pune Supergiants logo to ipl_logos\Rising_Pune_Supergiants.png
# Downloading Pune Warriors logo from: https://upload.wikimedia.org/wikipedia/en/4/4a/Pune_Warriors_India_IPL_Logo.png
# Saved Pune Warriors logo to ipl_logos\Pune_Warriors.png
# Downloading Deccan Chargers logo from: https://upload.wikimedia.org/wikipedia/en/a/a6/HyderabadDeccanChargers.png
# Saved Deccan Chargers logo to ipl_logos\Deccan_Chargers.png
# Downloading Kochi Tuskers Kerala logo from: https://upload.wikimedia.org/wikipedia/en/thumb/9/96/Kochi_Tuskers_Kerala_Logo.svg/1200px-Kochi_Tuskers_Kerala_Logo.svg.png
# Saved Kochi Tuskers Kerala logo to ipl_logos\Kochi_Tuskers_Kerala.png
# Logos are saved in: C:\Users\keval\Downloads\ipl_logos
